# %%
from sklearn import datasets
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from kneed import KneeLocator
from sklearn.metrics import silhouette_score
from yellowbrick.cluster import KElbowVisualizer
from sklearn.preprocessing import StandardScaler
iris = datasets.load_iris()
X = iris.data[:, :2]
y = iris.target
plt.scatter(X[:, 0], X[:, 1], c=y, cmap='gist_rainbow')
plt.xlabel('Lunghezza Sepale', fontsize=18)
plt.ylabel('Lunghezza Sepale', fontsize=18)
plt.show()

# %%
km=KMeans(n_clusters=3,random_state=0)
km.fit(X)
# Out:
# KMeans(n_clusters=3, random_state=0)

# %%
fig, axes = plt.subplots(1,2,figsize=(16,8))

axes[0].scatter(X[:,0],X[:,1],c=y,cmap='gist_rainbow',edgecolor='k',s=150)
axes[1].scatter(X[:,0],X[:,1],c=y,cmap='jet',edgecolor='k',s=150)

axes[0].set_title('REAL')
axes[1].set_title('EXPECTED')

plt.show()

# %%
print(silhouette_score(X,km.labels_, metric='euclidean'))
# Out:
# 0.4450525692083639

# %%
visualizer= KElbowVisualizer(km,k=(2,6),metric='silhouette',timings=False)
visualizer.fit(X)
visualizer.poof()
# Out:
# <Axes: title={'center': 'Silhouette Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='silhouette score'>
